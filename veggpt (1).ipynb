# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.1 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install openai

# %%
from langchain.llms import OpenAI

llm = OpenAI(openai_api_key="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")

# %%
lst = ["Raddish", "Cabbage", "Carrot", "Broccoli"]
prompts = ""
for id, ele in enumerate(lst):
    if id != len(lst)-1:
        prompts += ele + ", "
    else:
        prompts += "and " + ele

# %%
prompts
# Out:
# 'Raddish, Cabbage, Carrot, and Broccoli'

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("What are the cuisine we can make from {product}? Also give the cuisine recipe")
ans = prompt.format(product= prompts)

# %%
llm.predict(ans)
